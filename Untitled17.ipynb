# %%
#import libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# loading dataset as Pandas dataframe
df = pd.read_csv("automobileEDA.csv")
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# 0                9.0       111.0    5000.0       21          27  13495.0
# 1                9.0       111.0    5000.0       21          27  16500.0
# 2                9.0       154.0    5000.0       19          26  16500.0
# 3               10.0       102.0    5500.0       24          30  13950.0
# 4                8.0       115.0    5500.0       18          22  17450.0
#
#   city-L/100km  horsepower-binned  diesel  gas
# 0    11.190476             Medium       0    1
# 1    11.190476             Medium       0    1
# 2    12.368421             Medium       0    1
# 3     9.791667             Medium       0    1
# 4    13.055556             Medium       0    1
#
# [5 rows x 29 columns]

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %%
df.isnull()
# Out:
#      symboling  normalized-losses   make  aspiration  num-of-doors  \
# 0        False              False  False       False         False
# 1        False              False  False       False         False
# 2        False              False  False       False         False
# 3        False              False  False       False         False
# 4        False              False  False       False         False
# ..         ...                ...    ...         ...           ...
# 196      False              False  False       False         False
# 197      False              False  False       False         False
# 198      False              False  False       False         False
# 199      False              False  False       False         False
# 200      False              False  False       False         False
#
#      body-style  drive-wheels  engine-location  wheel-base  length  ...  \
# 0         False         False            False       False   False  ...
# 1         False         False            False       False   False  ...
# 2         False         False            False       False   False  ...
# 3         False         False            False       False   False  ...
# 4         False         False            False       False   False  ...
# ..          ...           ...              ...         ...     ...  ...
# 196       False         False            False       False   False  ...
# 197       False         False            False       False   False  ...
# 198       False         False            False       False   False  ...
# 199       False         False            False       False   False  ...
# 200       False         False            False       False   False  ...
#
#      compression-ratio  horsepower  peak-rpm  city-mpg  highway-mpg  price  \
# 0                False       False     False     False        False  False
# 1                False       False     False     False        False  False
# 2                False       False     False     False        False  False
# 3                False       False     False     False        False  False
# 4                False       False     False     False        False  False
# ..                 ...         ...       ...       ...          ...    ...
# 196              False       False     False     False        False  False
# 197              False       False     False     False        False  False
# 198              False       False     False     False        False  False
# 199              False       False     False     False        False  False
# 200              False       False     False     False        False  False
#
#      city-L/100km  horsepower-binned  diesel    gas
# 0           False              False   False  False
# 1           False              False   False  False
# 2           False              False   False  False
# 3           False              False   False  False
# 4           False              False   False  False
# ..            ...                ...     ...    ...
# 196         False              False   False  False
# 197         False              False   False  False
# 198         False              False   False  False
# 199         False              False   False  False
# 200         False              False   False  False
#
# [201 rows x 29 columns]

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               4
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# city-L/100km         0
# horsepower-binned    1
# diesel               0
# gas                  0
# dtype: int64

# %%
df["horsepower-binned"]
# Out:
# 0      Medium
# 1      Medium
# 2      Medium
# 3      Medium
# 4      Medium
#         ...
# 196    Medium
# 197      High
# 198    Medium
# 199    Medium
# 200    Medium
# Name: horsepower-binned, Length: 201, dtype: object

# %%
df.head(60)
# Out:
#     symboling  normalized-losses         make aspiration num-of-doors  \
# 0           3                122  alfa-romero        std          two
# 1           3                122  alfa-romero        std          two
# 2           1                122  alfa-romero        std          two
# 3           2                164         audi        std         four
# 4           2                164         audi        std         four
# 5           2                122         audi        std          two
# 6           1                158         audi        std         four
# 7           1                122         audi        std         four
# 8           1                158         audi      turbo         four
# 9           2                192          bmw        std          two
# 10          0                192          bmw        std         four
# 11          0                188          bmw        std          two
# 12          0                188          bmw        std         four
# 13          1                122          bmw        std         four
# 14          0                122          bmw        std         four
# 15          0                122          bmw        std          two
# 16          0                122          bmw        std         four
# 17          2                121    chevrolet        std          two
# 18          1                 98    chevrolet        std          two
# 19          0                 81    chevrolet        std         four
# 20          1                118        dodge        std          two
# 21          1                118        dodge        std          two
# 22          1                118        dodge      turbo          two
# 23          1                148        dodge        std         four
# 24          1                148        dodge        std         four
# 25          1                148        dodge        std         four
# 26          1                148        dodge      turbo         four
# 27         -1                110        dodge        std         four
# 28          3                145        dodge      turbo          two
# 29          2                137        honda        std          two
# 30          2                137        honda        std          two
# 31          1                101        honda        std          two
# 32          1                101        honda        std          two
# 33          1                101        honda        std          two
# 34          0                110        honda        std         four
# 35          0                 78        honda        std         four
# 36          0                106        honda        std          two
# 37          0                106        honda        std          two
# 38          0                 85        honda        std         four
# 39          0                 85        honda        std         four
# 40          0                 85        honda        std         four
# 41          1                107        honda        std          two
# 42          0                122        isuzu        std         four
# 43          2                122        isuzu        std          two
# 44          0                145       jaguar        std         four
# 45          0                122       jaguar        std         four
# 46          0                122       jaguar        std          two
# 47          1                104        mazda        std          two
# 48          1                104        mazda        std          two
# 49          1                104        mazda        std          two
# 50          1                113        mazda        std         four
# 51          1                113        mazda        std         four
# 52          3                150        mazda        std          two
# 53          3                150        mazda        std          two
# 54          3                150        mazda        std          two
# 55          3                150        mazda        std          two
# 56          1                129        mazda        std          two
# 57          0                115        mazda        std         four
# 58          1                129        mazda        std          two
# 59          0                115        mazda        std         four
#
#      body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0   convertible          rwd           front        88.6  0.811148  ...
# 1   convertible          rwd           front        88.6  0.811148  ...
# 2     hatchback          rwd           front        94.5  0.822681  ...
# 3         sedan          fwd           front        99.8  0.848630  ...
# 4         sedan          4wd           front        99.4  0.848630  ...
# 5         sedan          fwd           front        99.8  0.851994  ...
# 6         sedan          fwd           front       105.8  0.925997  ...
# 7         wagon          fwd           front       105.8  0.925997  ...
# 8         sedan          fwd           front       105.8  0.925997  ...
# 9         sedan          rwd           front       101.2  0.849592  ...
# 10        sedan          rwd           front       101.2  0.849592  ...
# 11        sedan          rwd           front       101.2  0.849592  ...
# 12        sedan          rwd           front       101.2  0.849592  ...
# 13        sedan          rwd           front       103.5  0.908217  ...
# 14        sedan          rwd           front       103.5  0.908217  ...
# 15        sedan          rwd           front       103.5  0.931283  ...
# 16        sedan          rwd           front       110.0  0.946660  ...
# 17    hatchback          fwd           front        88.4  0.678039  ...
# 18    hatchback          fwd           front        94.5  0.749159  ...
# 19        sedan          fwd           front        94.5  0.763095  ...
# 20    hatchback          fwd           front        93.7  0.755887  ...
# 21    hatchback          fwd           front        93.7  0.755887  ...
# 22    hatchback          fwd           front        93.7  0.755887  ...
# 23    hatchback          fwd           front        93.7  0.755887  ...
# 24        sedan          fwd           front        93.7  0.755887  ...
# 25        sedan          fwd           front        93.7  0.755887  ...
# 26        sedan          fwd           front        93.7  0.755887  ...
# 27        wagon          fwd           front       103.3  0.839020  ...
# 28    hatchback          fwd           front        95.9  0.832292  ...
# 29    hatchback          fwd           front        86.6  0.694858  ...
# 30    hatchback          fwd           front        86.6  0.694858  ...
# 31    hatchback          fwd           front        93.7  0.720807  ...
# 32    hatchback          fwd           front        93.7  0.720807  ...
# 33    hatchback          fwd           front        93.7  0.720807  ...
# 34        sedan          fwd           front        96.5  0.785199  ...
# 35        wagon          fwd           front        96.5  0.754926  ...
# 36    hatchback          fwd           front        96.5  0.804901  ...
# 37    hatchback          fwd           front        96.5  0.804901  ...
# 38        sedan          fwd           front        96.5  0.842864  ...
# 39        sedan          fwd           front        96.5  0.842864  ...
# 40        sedan          fwd           front        96.5  0.842864  ...
# 41        sedan          fwd           front        96.5  0.812590  ...
# 42        sedan          rwd           front        94.3  0.820279  ...
# 43    hatchback          rwd           front        96.0  0.829409  ...
# 44        sedan          rwd           front       113.0  0.959154  ...
# 45        sedan          rwd           front       113.0  0.959154  ...
# 46        sedan          rwd           front       102.0  0.921192  ...
# 47    hatchback          fwd           front        93.1  0.764536  ...
# 48    hatchback          fwd           front        93.1  0.764536  ...
# 49    hatchback          fwd           front        93.1  0.764536  ...
# 50        sedan          fwd           front        93.1  0.801538  ...
# 51        sedan          fwd           front        93.1  0.801538  ...
# 52    hatchback          rwd           front        95.3  0.812110  ...
# 53    hatchback          rwd           front        95.3  0.812110  ...
# 54    hatchback          rwd           front        95.3  0.812110  ...
# 55    hatchback          rwd           front        95.3  0.812110  ...
# 56    hatchback          fwd           front        98.8  0.854397  ...
# 57        sedan          fwd           front        98.8  0.854397  ...
# 58    hatchback          fwd           front        98.8  0.854397  ...
# 59        sedan          fwd           front        98.8  0.854397  ...
#
#     compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# 0                9.00       111.0    5000.0       21          27  13495.0
# 1                9.00       111.0    5000.0       21          27  16500.0
# 2                9.00       154.0    5000.0       19          26  16500.0
# 3               10.00       102.0    5500.0       24          30  13950.0
# 4                8.00       115.0    5500.0       18          22  17450.0
# 5                8.50       110.0    5500.0       19          25  15250.0
# 6                8.50       110.0    5500.0       19          25  17710.0
# 7                8.50       110.0    5500.0       19          25  18920.0
# 8                8.30       140.0    5500.0       17          20  23875.0
# 9                8.80       101.0    5800.0       23          29  16430.0
# 10               8.80       101.0    5800.0       23          29  16925.0
# 11               9.00       121.0    4250.0       21          28  20970.0
# 12               9.00       121.0    4250.0       21          28  21105.0
# 13               9.00       121.0    4250.0       20          25  24565.0
# 14               8.00       182.0    5400.0       16          22  30760.0
# 15               8.00       182.0    5400.0       16          22  41315.0
# 16               8.00       182.0    5400.0       15          20  36880.0
# 17               9.50        48.0    5100.0       47          53   5151.0
# 18               9.60        70.0    5400.0       38          43   6295.0
# 19               9.60        70.0    5400.0       38          43   6575.0
# 20               9.41        68.0    5500.0       37          41   5572.0
# 21               9.40        68.0    5500.0       31          38   6377.0
# 22               7.60       102.0    5500.0       24          30   7957.0
# 23               9.40        68.0    5500.0       31          38   6229.0
# 24               9.40        68.0    5500.0       31          38   6692.0
# 25               9.40        68.0    5500.0       31          38   7609.0
# 26               7.60       102.0    5500.0       24          30   8558.0
# 27               8.50        88.0    5000.0       24          30   8921.0
# 28               7.00       145.0    5000.0       19          24  12964.0
# 29               9.60        58.0    4800.0       49          54   6479.0
# 30               9.20        76.0    6000.0       31          38   6855.0
# 31              10.10        60.0    5500.0       38          42   5399.0
# 32               9.20        76.0    6000.0       30          34   6529.0
# 33               9.20        76.0    6000.0       30          34   7129.0
# 34               9.20        76.0    6000.0       30          34   7295.0
# 35               9.20        76.0    6000.0       30          34   7295.0
# 36               9.00        86.0    5800.0       27          33   7895.0
# 37               9.00        86.0    5800.0       27          33   9095.0
# 38               9.00        86.0    5800.0       27          33   8845.0
# 39               9.00        86.0    5800.0       27          33  10295.0
# 40               9.00       101.0    5800.0       24          28  12945.0
# 41               9.10       100.0    5500.0       25          31  10345.0
# 42               8.50        78.0    4800.0       24          29   6785.0
# 43               9.20        90.0    5000.0       24          29  11048.0
# 44               8.10       176.0    4750.0       15          19  32250.0
# 45               8.10       176.0    4750.0       15          19  35550.0
# 46              11.50       262.0    5000.0       13          17  36000.0
# 47               9.00        68.0    5000.0       30          31   5195.0
# 48               9.00        68.0    5000.0       31          38   6095.0
# 49               9.00        68.0    5000.0       31          38   6795.0
# 50               9.00        68.0    5000.0       31          38   6695.0
# 51               9.00        68.0    5000.0       31          38   7395.0
# 52               9.40       101.0    6000.0       17          23  10945.0
# 53               9.40       101.0    6000.0       17          23  11845.0
# 54               9.40       101.0    6000.0       17          23  13645.0
# 55               9.40       135.0    6000.0       16          23  15645.0
# 56               8.60        84.0    4800.0       26          32   8845.0
# 57               8.60        84.0    4800.0       26          32   8495.0
# 58               8.60        84.0    4800.0       26          32  10595.0
# 59               8.60        84.0    4800.0       26          32  10245.0
#
#    city-L/100km  horsepower-binned  diesel  gas
# 0     11.190476             Medium       0    1
# 1     11.190476             Medium       0    1
# 2     12.368421             Medium       0    1
# 3      9.791667             Medium       0    1
# 4     13.055556             Medium       0    1
# 5     12.368421             Medium       0    1
# 6     12.368421             Medium       0    1
# 7     12.368421             Medium       0    1
# 8     13.823529             Medium       0    1
# 9     10.217391                Low       0    1
# 10    10.217391                Low       0    1
# 11    11.190476             Medium       0    1
# 12    11.190476             Medium       0    1
# 13    11.750000             Medium       0    1
# 14    14.687500               High       0    1
# 15    14.687500               High       0    1
# 16    15.666667               High       0    1
# 17     5.000000                Low       0    1
# 18     6.184211                Low       0    1
# 19     6.184211                Low       0    1
# 20     6.351351                Low       0    1
# 21     7.580645                Low       0    1
# 22     9.791667             Medium       0    1
# 23     7.580645                Low       0    1
# 24     7.580645                Low       0    1
# 25     7.580645                Low       0    1
# 26     9.791667             Medium       0    1
# 27     9.791667                Low       0    1
# 28    12.368421             Medium       0    1
# 29     4.795918                Low       0    1
# 30     7.580645                Low       0    1
# 31     6.184211                Low       0    1
# 32     7.833333                Low       0    1
# 33     7.833333                Low       0    1
# 34     7.833333                Low       0    1
# 35     7.833333                Low       0    1
# 36     8.703704                Low       0    1
# 37     8.703704                Low       0    1
# 38     8.703704                Low       0    1
# 39     8.703704                Low       0    1
# 40     9.791667                Low       0    1
# 41     9.400000                Low       0    1
# 42     9.791667                Low       0    1
# 43     9.791667                Low       0    1
# 44    15.666667               High       0    1
# 45    15.666667               High       0    1
# 46    18.076923                NaN       0    1
# 47     7.833333                Low       0    1
# 48     7.580645                Low       0    1
# 49     7.580645                Low       0    1
# 50     7.580645                Low       0    1
# 51     7.580645                Low       0    1
# 52    13.823529                Low       0    1
# 53    13.823529                Low       0    1
# 54    13.823529                Low       0    1
# 55    14.687500             Medium       0    1
# 56     9.038462                Low       0    1
# 57     9.038462                Low       0    1
# 58     9.038462                Low       0    1
# 59     9.038462                Low       0    1
#
# [60 rows x 29 columns]

# %%
#calculate mean, median and mode of dat set height
mean = df["height"].mean()
median =df["height"].median()
mode = df["height"].mode()
print(mean);
print(mode);
print(mean)
# Out:
# 53.766666666666715
# 0    50.8
# dtype: float64
# 53.766666666666715

# %%
#distribution plot
sns.FacetGrid(df).map(sns.distplot,"height").add_legend()

# %%
#distribution plot
sns.FacetGrid(df,size=5).map(sns.distplot,"price").add_legend()
# Out:
# C:\Users\iloveyoumydreams\anaconda3\lib\site-packages\seaborn\axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#boxplot for price of cars
sns.boxplot(x="price",data=df)
plt.show()

# %%
# plot the relationship between “horsepower” and ”price”
plt.scatter(df["price"], df["horsepower"])
plt.title("Scatter Plot for horsepower vs price")
plt.xlabel("horsepower")
plt.ylabel("price")
# Out:
# Text(0, 0.5, 'price')

# %%
#boxplot
sns.boxplot(x="engine-location",y="price",data=df)
plt.show()

# %%
#boxplot to visualize the distribution of "price" with types of
#"drive-wheels"
sns.boxplot(x="drive-wheels", y="price",data=df)

# %%
# pair plot with plot type regression
sns.pairplot(df,vars = ['normalized-losses', 'price','horsepower'],
kind="reg")
plt.show()

# %%
#pair plot (matrix scatterplot) of few columns
sns.set(style="ticks", color_codes=True)
sns.pairplot(df,vars = ['symboling', 'normalized-losses','wheel-base'],
hue="drive-wheels")
plt.show()

# %%
from scipy import stats
corr = stats.pearsonr(df["price"], df["horsepower"])
print("p-value:\t", corr[1])
print("cor:\t\t", corr[0])
# Out:
# p-value:	 6.369057428261186e-48
# cor:		 0.8095745670036555

# %%
correlation = df.corr(method='pearson')
y=correlation >0.5
y
# Out:
#                    symboling  normalized-losses  wheel-base  length  width  \
# symboling               True              False       False   False  False
# normalized-losses      False               True       False   False  False
# wheel-base             False              False        True    True   True
# length                 False              False        True    True   True
# width                  False              False        True    True   True
# height                 False              False        True   False  False
# curb-weight            False              False        True    True   True
# engine-size            False              False        True    True   True
# bore                   False              False       False    True   True
# stroke                 False              False       False   False  False
# compression-ratio      False              False       False   False  False
# horsepower             False              False       False    True   True
# peak-rpm               False              False       False   False  False
# city-mpg               False              False       False   False  False
# highway-mpg            False              False       False   False  False
# price                  False              False        True    True   True
# city-L/100km           False              False       False    True   True
# diesel                 False              False       False   False  False
# gas                    False              False       False   False  False
#
#                    height  curb-weight  engine-size   bore  stroke  \
# symboling           False        False        False  False   False
# normalized-losses   False        False        False  False   False
# wheel-base           True         True         True  False   False
# length              False         True         True   True   False
# width               False         True         True   True   False
# height               True        False        False  False   False
# curb-weight         False         True         True   True   False
# engine-size         False         True         True   True   False
# bore                False         True         True   True   False
# stroke              False        False        False  False    True
# compression-ratio   False        False        False  False   False
# horsepower          False         True         True   True   False
# peak-rpm            False        False        False  False   False
# city-mpg            False        False        False  False   False
# highway-mpg         False        False        False  False   False
# price               False         True         True   True   False
# city-L/100km        False         True         True   True   False
# diesel              False        False        False  False   False
# gas                 False        False        False  False   False
#
#                    compression-ratio  horsepower  peak-rpm  city-mpg  \
# symboling                      False       False     False     False
# normalized-losses              False       False     False     False
# wheel-base                     False       False     False     False
# length                         False        True     False     False
# width                          False        True     False     False
# height                         False       False     False     False
# curb-weight                    False        True     False     False
# engine-size                    False        True     False     False
# bore                           False        True     False     False
# stroke                         False       False     False     False
# compression-ratio               True       False     False     False
# horsepower                     False        True     False     False
# peak-rpm                       False       False      True     False
# city-mpg                       False       False     False      True
# highway-mpg                    False       False     False      True
# price                          False        True     False     False
# city-L/100km                   False        True     False     False
# diesel                          True       False     False     False
# gas                            False       False     False     False
#
#                    highway-mpg  price  city-L/100km  diesel    gas
# symboling                False  False         False   False  False
# normalized-losses        False  False         False   False  False
# wheel-base               False   True         False   False  False
# length                   False   True          True   False  False
# width                    False   True          True   False  False
# height                   False  False         False   False  False
# curb-weight              False   True          True   False  False
# engine-size              False   True          True   False  False
# bore                     False   True          True   False  False
# stroke                   False  False         False   False  False
# compression-ratio        False  False         False    True  False
# horsepower               False   True          True   False  False
# peak-rpm                 False  False         False   False  False
# city-mpg                  True  False         False   False  False
# highway-mpg               True  False         False   False  False
# price                    False   True          True   False  False
# city-L/100km             False   True          True   False  False
# diesel                   False  False         False    True  False
# gas                      False  False         False   False   True

# %%
sns.heatmap(correlation,xticklabels=correlation.columns,
yticklabels=correlation.columns)
