# %%
import pandas as pd
df_red =pd.read_csv("winequality-red.csv")
df_white =pd.read_csv("wine_dataset.csv")
#df_wine=pd.read_csv('wine_dataset.csv')

# %%
df_red.iloc[100:110]
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 100            8.3             0.610         0.30             2.1      0.084
# 101            7.8             0.500         0.30             1.9      0.075
# 102            8.1             0.545         0.18             1.9      0.080
# 103            8.1             0.575         0.22             2.1      0.077
# 104            7.2             0.490         0.24             2.2      0.070
# 105            8.1             0.575         0.22             2.1      0.077
# 106            7.8             0.410         0.68             1.7      0.467
# 107            6.2             0.630         0.31             1.7      0.088
# 108            8.0             0.330         0.53             2.5      0.091
# 109            8.1             0.785         0.52             2.0      0.122
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 100                 11.0                  50.0   0.9972  3.40       0.61
# 101                  8.0                  22.0   0.9959  3.31       0.56
# 102                 13.0                  35.0   0.9972  3.30       0.59
# 103                 12.0                  65.0   0.9967  3.29       0.51
# 104                  5.0                  36.0   0.9960  3.33       0.48
# 105                 12.0                  65.0   0.9967  3.29       0.51
# 106                 18.0                  69.0   0.9973  3.08       1.31
# 107                 15.0                  64.0   0.9969  3.46       0.79
# 108                 18.0                  80.0   0.9976  3.37       0.80
# 109                 37.0                 153.0   0.9969  3.21       0.69
#
#      alcohol  quality
# 100     10.2        6
# 101     10.4        6
# 102      9.0        6
# 103      9.2        5
# 104      9.4        5
# 105      9.2        5
# 106      9.3        5
# 107      9.3        5
# 108      9.6        6
# 109      9.3        5

# %%
df_red.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
import seaborn as sns
sns.set(rc={'figure.figsize': (14, 8)})
sns.countplot(df_red['quality'])

# %%
sns.pairplot(df_red)

# %%
sns.heatmap(df_red.corr(), annot=True, fmt='.2f', linewidths=2)

# %%
sns.distplot(df_red['alcohol'])

# %%
from scipy.stats import skew
skew(df_red['alcohol'])
# Out:
# 0.8600210646566755

# %%
sns.boxplot(x='quality', y='alcohol', data = df_red)

# %%
sns.boxplot(x='quality', y='alcohol', data = df_red, showfliers=False)

# %%
sns.jointplot(x='alcohol',y='pH',data=df_red, kind='reg')

# %%
from scipy.stats import pearsonr
def get_correlation(column1, column2, df):
    pearson_corr, p_value = pearsonr(df[column1], df[column2])
    print("Correlation between {} and {} is {}".format(column1,column2, pearson_corr))
    print("P-value of this correlation is {}".format(p_value))

# %%
get_correlation('alcohol','pH', df_red)
# Out:
# Correlation between alcohol and pH is 0.2056325085054989
# P-value of this correlation is 9.964497741462162e-17

# %%
df_red['quality_label'] = df_red['quality'].apply(lambda value: ('low' if
value <= 5 else 'medium') if value <= 7 else 'high')
df_red['quality_label'] = pd.Categorical(df_red['quality_label'],
categories=['low', 'medium', 'high'])

# %%
df_red['quality_label'].value_counts()
# Out:
# medium    837
# low       744
# high       18
# Name: quality_label, dtype: int64

# %%
df_wine['style']
# Out:
# 0       white
# 1       white
# 2       white
# 3       white
# 4       white
#         ...
# 6492    white
# 6493    white
# 6494    white
# 6495    white
# 6496    white
# Name: style, Length: 6497, dtype: object

# %%
df_wine.iloc[50:150]
# Out:
#      fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 50             8.8              0.66         0.26             1.7      0.074
# 51             6.6              0.52         0.04             2.2      0.069
# 52             6.6              0.50         0.04             2.1      0.068
# 53             8.6              0.38         0.36             3.0      0.081
# 54             7.6              0.51         0.15             2.8      0.110
# ..             ...               ...          ...             ...        ...
# 145            8.1              0.67         0.55             1.8      0.117
# 146            5.8              0.68         0.02             1.8      0.087
# 147            7.6              0.49         0.26             1.6      0.236
# 148            6.9              0.49         0.10             2.3      0.074
# 149            8.2              0.40         0.44             2.8      0.089
#
#      free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 50                   4.0                  23.0   0.9971  3.15       0.74
# 51                   8.0                  15.0   0.9956  3.40       0.63
# 52                   6.0                  14.0   0.9955  3.39       0.64
# 53                  30.0                 119.0   0.9970  3.20       0.56
# 54                  33.0                  73.0   0.9955  3.17       0.63
# ..                   ...                   ...      ...   ...        ...
# 145                 32.0                 141.0   0.9968  3.17       0.62
# 146                 21.0                  94.0   0.9944  3.54       0.52
# 147                 10.0                  88.0   0.9968  3.11       0.80
# 148                 12.0                  30.0   0.9959  3.42       0.58
# 149                 11.0                  43.0   0.9975  3.53       0.61
#
#      alcohol  quality  style
# 50       9.2        5  white
# 51       9.4        6  white
# 52       9.4        6  white
# 53       9.4        5  white
# 54      10.2        6  white
# ..       ...      ...    ...
# 145      9.4        5  white
# 146     10.0        5  white
# 147      9.3        5  white
# 148     10.2        6  white
# 149     10.5        6  white
#
# [100 rows x 13 columns]

# %%
df_white['quality_label'] = df_white['quality'].apply(lambda value: ('low'
if value <= 5 else 'medium') if value <= 7 else 'high')
df_white['quality_label'] = pd.Categorical(df_white['quality_label'],
categories=['low', 'medium', 'high'])

# %%
df_wines = pd.concat([df_red, df_white])

# %%
df_wines = df_wines.sample(frac=1.0,
random_state=42).reset_index(drop=True)

# %%
df_wines.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            NaN               NaN          NaN             NaN      0.045
# 1            NaN               NaN          NaN             NaN      0.050
# 2            NaN               NaN          NaN             NaN      0.036
# 3            NaN               NaN          NaN             NaN      0.051
# 4            NaN               NaN          NaN             NaN      0.047
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                  NaN                   NaN  0.99249  2.95       0.39
# 1                  NaN                   NaN  0.99002  3.00       0.45
# 2                  NaN                   NaN  0.99521  3.34       0.52
# 3                  NaN                   NaN  0.99160  3.37       0.43
# 4                  NaN                   NaN  0.99896  3.10       0.45
#
#    alcohol  quality quality_label  fixed_acidity  volatile_acidity  \
# 0     10.1        5           low            8.6              0.31
# 1     12.4        6        medium            8.0              0.27
# 2     10.2        6        medium            6.1              0.32
# 3     11.0        3           low            6.2              0.23
# 4      8.9        6        medium            6.0              0.28
#
#    citric_acid  residual_sugar  free_sulfur_dioxide  total_sulfur_dioxide  \
# 0         0.30             0.9                 16.0                 109.0
# 1         0.33             1.2                 41.0                 103.0
# 2         0.33            10.7                 27.0                  98.0
# 3         0.35             0.7                 24.0                 111.0
# 4         0.24            17.8                 42.0                 111.0
#
#    style
# 0  white
# 1  white
# 2  white
# 3  white
# 4  white

# %%
subset_attr = ['alcohol', 'density', 'pH', 'quality']
low = round(df_wines[df_wines['quality_label'] ==
'low'][subset_attr].describe(), 2)
medium = round(df_wines[df_wines['quality_label'] ==
'medium'][subset_attr].describe(), 2)
high = round(df_wines[df_wines['quality_label'] ==
'high'][subset_attr].describe(), 2)
pd.concat([low, medium, high], axis=1,
keys=[' Low Quality Wine',
' Medium Quality Wine',
' High Quality Wine'])
# Out:
#        Low Quality Wine                             Medium Quality Wine  \
#                 alcohol  density       pH  quality              alcohol
# count           3128.00  3128.00  3128.00  3128.00              4752.00
# mean               9.89     1.00     3.24     4.89                10.81
# std                0.82     0.00     0.16     0.35                 1.18
# min                8.00     0.99     2.74     3.00                 8.40
# 25%                9.30     0.99     3.13     5.00                 9.90
# 50%                9.60     1.00     3.22     5.00                10.80
# 75%               10.30     1.00     3.35     5.00                11.70
# max               14.90     1.00     3.90     5.00                14.20
#
#                                   High Quality Wine
#        density       pH  quality            alcohol density      pH quality
# count  4752.00  4752.00  4752.00             216.00  216.00  216.00  216.00
# mean      0.99     3.24     6.27              11.73    0.99    3.23    8.02
# std       0.00     0.16     0.44               1.27    0.00    0.16    0.15
# min       0.99     2.72     6.00               8.50    0.99    2.88    8.00
# 25%       0.99     3.12     6.00              11.00    0.99    3.13    8.00
# 50%       0.99     3.23     6.00              12.00    0.99    3.23    8.00
# 75%       1.00     3.34     7.00              12.60    0.99    3.33    8.00
# max       1.04     4.01     7.00              14.00    1.00    3.72    9.00

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
fig = df_wines.hist(bins=15, color='fuchsia', edgecolor='darkmagenta',
linewidth=1.0, xlabelsize=10, ylabelsize=10, xrot=45, yrot=0,
figsize=(10,9), grid=False)
plt.tight_layout(rect=(0, 0, 1.5, 1.5))

# %%
fig, (ax) = plt.subplots(1, 1, figsize=(14,8))

# %%
hm = sns.heatmap(df_wines.corr(),
ax=ax,
cmap="bwr",
annot=True,
fmt='.2f',
linewidths=.05)

# %%
fig.subplots_adjust(top=0.93)
fig.suptitle('Combined Wine Attributes and their CorrelationHeatmap', fontsize=14, fontweight='bold')
# Out:
# Text(0.5, 0.98, 'Combined Wine Attributes and their CorrelationHeatmap')

# %%
fig = plt.figure(figsize=(16, 8))
sns.countplot(data=df_wines, x="quality", hue="wine_category")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-633f1b657998> in <module>
#       1 fig = plt.figure(figsize=(16, 8))
# ----> 2 sns.countplot(data=df_wines, x="quality", hue="wine_category")
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3547         raise TypeError("Must pass values for either `x` or `y`")
#    3548
# -> 3549     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3550                           estimator, ci, n_boot, units, seed,
#    3551                           orient, color, palette, saturation,
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1600                  errwidth, capsize, dodge):
#    1601         """Initialize the plotter."""
# -> 1602         self.establish_variables(x, y, hue, data, orient,
#    1603                                  order, hue_order, units)
#    1604         self.establish_colors(color, palette, saturation)
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     150                 if isinstance(var, str):
#     151                     err = "Could not interpret input '{}'".format(var)
# --> 152                     raise ValueError(err)
#     153
#     154             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'wine_category'
